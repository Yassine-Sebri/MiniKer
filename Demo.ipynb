# %%
# Essentials
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Importing NeuralNetwork class
from NeuralNetwork import NeuralNetwork

# %%
# Creating the dataset 
X = np.arange(-np.pi, np.pi, 0.005)
y = np.sin(X) * np.sin(2 * X) * np.sin(3 * X)
plt.plot(X, y);
plt.show();
X = X.reshape(1257, 1)
y = y.reshape(1257, 1)

# %%
# Creating an instance of the NeuralNetwork Class
NN = NeuralNetwork(X, y, [128, 128, 128, 128], activation='Relu', objective='regression')
NN.summary()
NN.compile(learning_rate=0.0001)
# Out:
# Input layer has 1 neuron.
# Weight matrix 1 has (1, 128) shape.
# Hidden layer 1 has 128 neurons.
# Weight matrix 2 has (129, 128) shape.
# Hidden layer 2 has 128 neurons.
# Weight matrix 3 has (129, 128) shape.
# Hidden layer 3 has 128 neurons.
# Weight matrix 4 has (129, 128) shape.
# Hidden layer 4 has 128 neurons.
# Weight matrix 5 has (129, 1) shape.
# Output layer has 1 neuron.

# %%
#training
r = NN.train(epochs=10000)
# Out:
# epoch 0
# loss: 0.11633990323181098
# -----------------------------------------------------
# epoch 1000
# loss: 0.04402757910495747
# -----------------------------------------------------
# epoch 2000
# loss: 0.039099044834354744
# -----------------------------------------------------
# epoch 3000
# loss: 0.03468339316886373
# -----------------------------------------------------
# epoch 4000
# loss: 0.023345323033669
# -----------------------------------------------------
# epoch 5000
# loss: 0.01745790804535832
# -----------------------------------------------------
# epoch 6000
# loss: 0.01064672028510139
# -----------------------------------------------------
# epoch 7000
# loss: 0.008185365398193423
# -----------------------------------------------------
# epoch 8000
# loss: 0.009703760525194675
# -----------------------------------------------------
# epoch 9000
# loss: 0.005546499964678659
# -----------------------------------------------------
# epoch 10000
# loss: 0.005842341815950779
# -----------------------------------------------------

# %%
plt.plot(r);
plt.xlabel('Epochs');
plt.ylabel('Loss');

# %%
plt.figure(figsize=(16,4))
plt.subplot(1, 2, 1)
plt.plot(X.reshape(1257), NN.predict().reshape(1257))
plt.subplot(1, 2, 2)
plt.plot(X.reshape(1257), y.reshape(1257))
plt.show()
